# %%
import numpy as np
xvg_file = "Data/1hz3_T310.run.25000000.energy.xvg"
data = np.loadtxt(xvg_file, comments=['@', '#'], usecols=(0,6))
print(data)
# Out:
# [[    0.         137.956879]
#  [  100.         137.819077]
#  [  200.         137.437531]
#  ...
#  [49800.         138.378967]
#  [49900.         138.065186]
#  [50000.         138.603043]]

# %%
import numpy as np
import matplotlib.pyplot as plt

xvg_file = "Data/1hz3_T310.run.25000000.energy.xvg"
data = np.loadtxt(xvg_file, comments=['@', '#'])
time_ns = data[:, 0] * 1000

# Assuming columns 1 to 6 represent Potential Energy, Kinetic Energy, Total Energy, Temperature, Pressure, and Volume respectively.
quantities = ['Potential Energy', 'Kinetic Energy', 'Total Energy', 'Temperature', 'Pressure', 'Volume']

for i in range(6):
    plt.figure(figsize=(12, 4))  # Create a new figure for each quantity
    
    plt.plot(time_ns, data[:, i + 1])
    plt.xlabel('Time (ns)')
    plt.ylabel(f'{quantities[i]} Value')
    plt.title(f'{quantities[i]} vs. Time (ns)')
    plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xvg_file = "Data/1hz3_T310.run.25000000.energy.xvg"
data = np.loadtxt(xvg_file, comments=['@', '#'])


time_ns = data[:, 0] * 1000  
kinetic_energy = data[:, 1]  
temperature = data[:, 3]  

# Create a figure and a left (temperature) and right (kinetic energy) axes
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot temperature on the left axis (ax1)
ax1.set_xlabel('Time (ns)')
ax1.set_ylabel('Temperature (K)', color='tab:blue')
ax1.plot(time_ns, temperature, color='tab:blue', label='Temperature')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis on the right (kinetic energy)
ax2 = ax1.twinx()
ax2.set_ylabel('Kinetic Energy', color='tab:red')
ax2.plot(time_ns, kinetic_energy, color='tab:red', label='Kinetic Energy')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Add legends for both lines
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

# Title and grid
plt.title('Temperature and Kinetic Energy vs. Time')
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
