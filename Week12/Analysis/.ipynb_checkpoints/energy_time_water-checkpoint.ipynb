# %%
import numpy as np
import matplotlib.pyplot as plt
from MDAnalysis.analysis.rdf import InterRDF
import MDAnalysis as mda

# %%
Step, Time, Kin, Temp, Pot, ConsQty, UsedTime = np. loadtxt('../Runs/Water/water_aimd_1ns_every0.5fs-1.ener', skiprows=1, unpack=True)

# %%
plt.plot(Time, Pot)
plt.xlabel("Time(fs)")
plt.ylabel("Energy")
plt.title("Energy vs Time of Water")
# Specify the directory to save the figure
save_directory = '../Figures'

# Ensure the directory exists, create if not
import os
os.makedirs(save_directory, exist_ok=True)

# Save the figure to the specified directory
plt.savefig(os.path.join(save_directory, 'energy_vs_time_plot.png'))
plt.show()
